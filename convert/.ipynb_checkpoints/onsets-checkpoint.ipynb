# %%
import os
from glob import glob
from csv import reader, writer
import numpy as np

# %%
csv_path='/om/user/zqi/projects/CASL/Results/Beh/sent/CASL_data/pylog'
#data_dir='/om/user/zqi/projects/CASL/Results/Imaging/openfmri'
data_dir='/om/user/cdla/projects/casl/openfmri/'
subj_list=sorted([os.path.basename(x) for x in glob(os.path.join(data_dir,'CASL*'))])

# %%
for subj in subj_list:
    print subj
    if subj[-3]=='1':
        for run in range(1,3):
            try:
                csv=sorted(glob(os.path.join(csv_path,subj[-5:]+'_fMRI_sent_run%d*.log'%run)))[-1]
                log_data=np.genfromtxt(csv,delimiter='\t',dtype='str')
                #trigger_time=float([row[0] for row in log_data if row[2]=='Keypress: num_add'][0])
                onset_times=[float(row[0]) for row in log_data if row[2]=='Sound  started']
                onset_conditions=[row[2] for row in log_data if 'sound=/' in row[2]]
                onsets=[[],[],[]]
                for idx,trial in enumerate(onset_conditions):
                    if 'silly' in trial:
                        onsets[0].append(onset_times[idx])
                    elif 'mandarin' in trial:
                        onsets[1].append(onset_times[idx])
                    elif 'english' in trial:
                        onsets[2].append(onset_times[idx])
                onset_dir=data_dir+ '/%s/model/model001/onsets/task001_run%03d'%(subj,run)
                if not os.path.exists(onset_dir):
                    os.makedirs(onset_dir)
                for idx,condition in enumerate(['mal','mandarin','english']):
                    with open(os.path.join(onset_dir,'cond%03d.txt'%(idx+1)),'wb') as csvfile:
                        onset_writer=writer(csvfile,delimiter='\t')
                        for onset in onsets[idx]:
                            onset_writer.writerow(['%.1f'%onset,'%.1f'%18,'%.1f'%1])
            except:
                continue
    elif subj[-3]=='2':
        for run in range(3,5):
            try:
                csv=sorted(glob(os.path.join(csv_path,'131'+subj[-2:]+'_fMRI_sent_run%d*.log'%run)))[-1]
                log_data=np.genfromtxt(csv,delimiter='\t',dtype='str')
                #trigger_time=float([row[0] for row in log_data if row[2]=='Keypress: num_add'][0])
                onset_times=[float(row[0]) for row in log_data if row[2]=='Sound  started']
                onset_conditions=[row[2] for row in log_data if 'sound=/' in row[2]]
                onsets=[[],[],[]]
                print subj,run
                for idx,trial in enumerate(onset_conditions):
                    if 'silly' in trial:
                        onsets[0].append(onset_times[idx])
                    elif 'mandarin' in trial:
                        onsets[1].append(onset_times[idx])
                    elif 'english' in trial:
                        onsets[2].append(onset_times[idx])
                onset_dir=data_dir+'%s/model/model001/onsets/task001_run%03d'%(subj,run-2)
                if not os.path.exists(onset_dir):
                    os.makedirs(onset_dir)
                for idx,condition in enumerate(['mal','mandarin','english']):
                    with open(os.path.join(onset_dir,'cond%03d.txt'%(idx+1)),'wb') as csvfile:
                        onset_writer=writer(csvfile,delimiter='\t')
                        for onset in onsets[idx]:
                            onset_writer.writerow(['%.1f'%onset,'%.1f'%18,'%.1f'%1])
            except:
                continue
# Out:
# CASL13101
# CASL13103
# CASL13104
# CASL13105
# CASL13107
# CASL13108
# CASL13109
# CASL13110
# CASL13112
# CASL13113
# CASL13114
# CASL13115
# CASL13117
# CASL13118
# CASL13119
# CASL13120
# CASL13122
# CASL13124
# CASL13125
# CASL13126
# CASL13128
# CASL13129
# CASL13129A
# CASL13130
# CASL13131
# CASL13132
# CASL13201
# CASL13201 3
# CASL13201 4
# CASL13202
# CASL13202 3
# CASL13202 4
# CASL13204
# CASL13204 3
# CASL13204 4
# CASL13206
# CASL13206 3
# CASL13206 4
# CASL13208
# CASL13208 3
# CASL13208 4
# CASL13210
# CASL13210 3
# CASL13210 4
# CASL13211
# CASL13211 3
# CASL13211 4
# CASL13212
# CASL13212 3
# CASL13212 4
# CASL13214
# CASL13214 3
# CASL13214 4
# CASL13216
# CASL13216 3
# CASL13216 4
# CASL13217
# CASL13217 3
# CASL13217 4
# CASL13219
# CASL13219 3
# CASL13219 4
# CASL13220
# CASL13220 3
# CASL13220 4
# CASL13221
# CASL13221 3
# CASL13221 4
# CASL13222
# CASL13222 3
# CASL13222 4
# CASL13223
# CASL13223 3
# CASL13223 4
# CASL13224
# CASL13224 3
# CASL13224 4
# CASL13225
# CASL13225 3
# CASL13225 4
# CASL13226
# CASL13226 3
# CASL13228
# CASL13228 3
# CASL13228 4
# CASL13230
# CASL13230 3
# CASL13230 4
